# %% [markdown]
# # 📊 Analyse du Dataset Anime
#
# ## 🎯 Objectif
# Ce notebook a pour but d'explorer, nettoyer et analyser un dataset contenant des informations sur des animes.
#
# ## 📚 Table des matières
# 1. [Importation des bibliothèques](#import)
# 2. [Chargement des données](#chargement)
# 3. [Exploration initiale](#exploration)
# 4. [Nettoyage des données](#nettoyage)
# 5. [Vérification finale](#verification)
# 6. [Sauvegarde](#sauvegarde)
#
# ---

# %% [markdown]
# ## 1. 📦 Importation des bibliothèques {#import}
#
# Importation des bibliothèques Python nécessaires pour l'analyse :
# - **pandas** : manipulation et analyse de données
# - **numpy** : calculs numériques

# %%
# Importation des librairies nécessaires
import pandas as pd
import numpy as np

print("✅ Librairies importées avec succès")
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# ✅ Librairies importées avec succès
# Pandas version: 3.0.0
# NumPy version: 2.4.1

# %% [markdown]
# ## 2. 📂 Chargement des données {#chargement}
#
# Chargement du fichier CSV contenant les données des animes.
#
# **Source** : `data/animes.csv`

# %%
# Fonction chargement dataset
df = pd.read_csv("data/animes.csv")

print(f"Dataset contient : {df.shape[0]} lignes et {df.shape[1]} colonnes.")
# Out:
# Dataset contient : 61 lignes et 17 colonnes.

# %% [markdown]
# ## 3. 🔍 Exploration initiale des données {#exploration}
#
# ### 3.1 Aperçu du dataset
# Affichage des premières lignes pour comprendre la structure des données.

# %%
# Affichage des 10 premières lignes
df.head(10)
# Out:
#                               Anime              Genre_Tags       Source  \
# 0                            Naruto         Action / Shonen        Manga
# 1                            Trigun         Sci-Fi / Action        Manga
# 2                     Dragon Ball Z         Action / Shonen        Manga
# 3  Fullmetal Alchemist: Brotherhood     Aventure / Military        Manga
# 4                      Cowboy Bebop           Sci-Fi / Noir     Original
# 5                  Sword Art Online        Isekai / Romance  Light Novel
# 6                           Re:Zero  Isekai / Psychologique  Light Novel
# 7                         Dr. Stone      Sci-Fi / Adventure        Manga
# 8                         One Piece      Adventure / Shonen        Manga
# 9                         Blue Lock        Sport / Thriller        Manga
#
#    Nb_Episodes    Status             Studio   Date_Pub  Note_Globale  \
# 0          220      Fini     Studio Pierrot 2002-10-03           8.4
# 1           26      Fini           Madhouse 1998-04-01           8.2
# 2          291      Fini     Toei Animation 1989-04-26           8.7
# 3           64      Fini              Bones 2009-04-05           9.1
# 4           26      Fini            Sunrise 1998-04-03           8.8
# 5           25      Fini       A-1 Pictures 2012-07-08           7.2
# 6           50      Fini          White Fox 2016-04-04           8.2
# 7           57  En cours  TMS Entertainment 2019-07-05           8.3
# 8         1090  En cours     Toei Animation 1999-10-20           8.7
# 9           36  En cours               8bit 2022-10-09           8.2
#
#    Note_Meilleur_Ep                   Meilleur_Ep_Titre  \
# 0               9.6           Ep 133: Le cri des larmes
# 1               9.1               Ep 24: Le péché (Sin)
# 2               9.4      Ep 237: Le sacrifice d'un père
# 3               9.6  Ep 63: De l'autre côté de la porte
# 4               9.7     Ep 26: The Real Folk Blues Pt.2
# 5               8.9       Ep 9: Le démon aux yeux bleus
# 6               9.8      Ep 15: L'extérieur de la folie
# 7               9.1       Ep 24: Les voix vers l'infini
# 8               9.8    Ep 1015: Chapeau de Paille Luffy
# 9               9.3            Ep 11: La dernière pièce
#
#                                     Comm_Meilleur_Ep  Note_Pire_Ep  \
# 0    Animation fluide et combat viscéral incroyable.           5.8
# 1  Conclusion tragique de l'arc Wolfwood, émotion...           6.5
# 2    Rédemption ultime de Vegeta, sommet émotionnel.           5.9
# 3  Sacrifice thématique parfait, conclusion magis...           6.3
# 4                    Fin poétique et iconique. Bang.           7.2
# 5            Hype absolue, révélation du Dual Wield.           5.9
# 6  Chef d'oeuvre d'horreur et de désespoir, fin l...           7.6
# 7  Conclusion S1 émouvante, lien passé-futur subl...           7.1
# 8  Réalisation cinéma époustouflante, sommet de W...           5.6
# 9  Le puzzle s'assemble, le but d'Isagi est jouis...           6.0
#
#                          Pire_Ep_Titre  \
# 0     Ep 26: Journal de Konoha (Recap)
# 1     Ep 13: Vash the Stampede (Recap)
# 2  Ep 39: Amis ou ennemis (Fake Namek)
# 3             Ep 27: Intermède (Recap)
# 4       Ep 23: Boogie Woogie Feng Shui
# 5     Ep 22: La grande quête (Alfheim)
# 6     Ep 13: Le chevalier autoproclamé
# 7               Ep 14: Master of Flame
# 8          Ep 336: Chopperman (Filler)
# 9                    Ep 22: Voice (S2)
#
#                                         Comm_Pire_Ep  \
# 0                     Remplissage inutile, à sauter.
# 1           Résumé de mi-saison qui casse le rythme.
# 2   Filler ennuyeux sur une fausse planète, inutile.
# 3           Episode récapitulatif cassant le rythme.
# 4              Intrigue faible et rythme un peu mou.
# 5  Rythme lent et enjeux faibles dans l'arc des f...
# 6  Episode gênant (cringe) voulu par le scénario,...
# 7   Rythme un peu plus lent, préparation de tournoi.
# 8  Episode hors-série enfantin totalement dispens...
# 9  Qualité d'animation en baisse critique, beauco...
#
#                                        Comm_Saison_1  \
# 0           Arc Zabuza très émouvant, bases solides.
# 1          Début western comique, Vash joue l'idiot.
# 2  Introduction des Saiyans et codes du Shonen po...
# 3   Début effréné, traumatisme Nina Tucker marquant.
# 4   Formation de l'équipe et choc visuel à l'église.
# 5  Concept 'Jeu de la mort' accrocheur, romance f...
# 6  Boucle temporelle et basculement vers le thril...
# 7  Le réveil dans un monde de pierre, la science ...
# 8  Saga East Blue : La formation de l'équipage, n...
# 9  Concept Battle Royale de foot, égoïsme pur mis...
#
#                                        Comm_Saison_2  \
# 0       Examen Chuunin introduit une tension sombre.
# 1    Virage dramatique sombre avec les Gung-Ho Guns.
# 2   Aventure spatiale et tension tactique sur Namek.
# 3   Complot politique et Mustang brille contre Lust.
# 4  Exploration mélancolique du passé (Jupiter Jazz).
# 5  Chute de qualité, méchant caricatural et moins...
# 6  Arc Sanctuaire dense en dialogues et passé des...
# 7  Stone Wars : Conflit idéologique et batailles ...
# 8  Saga Alabasta : Premier grand défi géopolitiqu...
# 9  Sélection U-20, enjeux d'équipe vs individualité.
#
#                                        Comm_Saison_3  Annee  Mois  Jour
# 0                    Combat Lee vs Gaara légendaire.   2002    10     3
# 1  Révélations philosophiques sur le passé et Kni...   1998     4     1
# 2  Transformation Super Saiyan iconique, combat é...   1989     4    26
# 3  Ambiance militaire froide à Briggs, tension mo...   2009     4     5
# 4  Confrontation fatale avec le Syndicat et Vicious.   1998     4     3
# 5  Retour en force avec Gun Gale Online et ton pl...   2012     7     8
# 6  Résolution intelligente, Subaru grandit et uti...   2016     4     4
# 7  New World : Exploration maritime et découverte...   2019     7     5
# 8  Saga Skypiea/Water 7 : Aventure céleste puis d...   1999    10    20
# 9                                      (Non diffusé)   2022    10     9

# %% [markdown]
# ### 3.2 Structure du dataset
# Liste des colonnes disponibles et leurs types de données.

# %%
# Affichage des colonnes disponibles
print("📋 Colonnes disponibles :")
print("-"* 40)

# Liste des colonnes avec leur index
for i, col in enumerate(df.columns, 1):
    print(i,col)
# Out:
# 📋 Colonnes disponibles :
# ----------------------------------------
# 1 Anime
# 2 Genre_Tags
# 3 Source
# 4 Nb_Episodes
# 5 Status
# 6 Studio
# 7 Date_Pub
# 8 Note_Globale
# 9 Note_Meilleur_Ep
# 10 Meilleur_Ep_Titre
# 11 Comm_Meilleur_Ep
# 12 Note_Pire_Ep
# 13 Pire_Ep_Titre
# 14 Comm_Pire_Ep
# 15 Comm_Saison_1
# 16 Comm_Saison_2
# 17 Comm_Saison_3

# %% [markdown]
# ### 3.3 Informations détaillées
# Analyse des types de données, de la mémoire utilisée et des valeurs non nulles.

# %%
# Affichage des informations du DataFrame
df.info()
print("-"*70)
# Affiche les statistiques (min, max, moyenne)
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Anime              61 non-null     str
#  1   Genre_Tags         61 non-null     str
#  2   Source             61 non-null     str
#  3   Nb_Episodes        61 non-null     int64
#  4   Status             61 non-null     str
#  5   Studio             61 non-null     str
#  6   Date_Pub           61 non-null     str
#  7   Note_Globale       61 non-null     float64
#  8   Note_Meilleur_Ep   61 non-null     float64
#  9   Meilleur_Ep_Titre  61 non-null     str
#  10  Comm_Meilleur_Ep   61 non-null     str
#  11  Note_Pire_Ep       61 non-null     float64
#  12  Pire_Ep_Titre      61 non-null     str
#  13  Comm_Pire_Ep       61 non-null     str
#  14  Comm_Saison_1      61 non-null     str
#  15  Comm_Saison_2      61 non-null     str
#  16  Comm_Saison_3      51 non-null     str
# dtypes: float64(3), int64(1), str(13)
# memory usage: 8.2 KB
# ----------------------------------------------------------------------
#        Nb_Episodes  Note_Globale  Note_Meilleur_Ep  Note_Pire_Ep
# count    61.000000     61.000000         61.000000     61.000000
# mean     90.737705      8.316393          9.318033      6.719672
# std     162.055227      0.521594          0.469932      1.369650
# min       3.000000      6.000000          8.200000      0.000000
# 25%      24.000000      8.100000          9.100000      6.200000
# 50%      37.000000      8.400000          9.400000      7.200000
# 75%      76.000000      8.600000          9.700000      7.500000
# max    1090.000000      9.300000          9.900000      8.400000

# %% [markdown]
# ### 3.4 Valeurs manquantes
# Identification et quantification des valeurs manquantes par colonne.

# %%
# Décompte des valeurs manquantes par colonne
print("🔍 Nombre de valeurs manquantes par colonne :")
print(df.isnull().sum())
# Out:
# 🔍 Nombre de valeurs manquantes par colonne :
# Anime                 0
# Genre_Tags            0
# Source                0
# Nb_Episodes           0
# Status                0
# Studio                0
# Date_Pub              0
# Note_Globale          0
# Note_Meilleur_Ep      0
# Meilleur_Ep_Titre     0
# Comm_Meilleur_Ep      0
# Note_Pire_Ep          0
# Pire_Ep_Titre         0
# Comm_Pire_Ep          0
# Comm_Saison_1         0
# Comm_Saison_2         0
# Comm_Saison_3        10
# dtype: int64

# %% [markdown]
# ### 3.5 Traitement des dates
# Conversion de la colonne `Date_Pub` en format datetime et extraction des composantes temporelles.
#
# **Colonnes créées** :
# - `Annee` : année de publication
# - `Mois` : mois de publication
# - `Jour` : jour de publication
#
# > **Note** : L'extraction du jour et du mois peut être utile pour analyser la saisonnalité des sorties.

# %%
# Conversion de la colonne 'Date_Pub' en format date
df ['Date_Pub'] = pd.to_datetime (df ['Date_Pub'])

# Extraction de l'année, du mois et du jour de publication
df ['Annee'] = df ['Date_Pub'].dt.year
df ['Mois'] = df ['Date_Pub'].dt.month
df ['Jour'] = df ['Date_Pub'].dt.day
# Doute sur la pertinence de cette extraction (day & month, utile ?)


print("📅 Dates converties et extraites :")
print("-"*65)

print(df[['Anime', 'Date_Pub', 'Annee', 'Mois', 'Jour']].head(10))
print (f"\n✅ Types de 'Date_Pub' après conversion : {df['Date_Pub'].dtype}")

print(f"\n✅ Dates converties et extraites avec succès.")
print("-"*65)
# Out:
# 📅 Dates converties et extraites :
# -----------------------------------------------------------------
#                               Anime   Date_Pub  Annee  Mois  Jour
# 0                            Naruto 2002-10-03   2002    10     3
# 1                            Trigun 1998-04-01   1998     4     1
# 2                     Dragon Ball Z 1989-04-26   1989     4    26
# 3  Fullmetal Alchemist: Brotherhood 2009-04-05   2009     4     5
# 4                      Cowboy Bebop 1998-04-03   1998     4     3
# 5                  Sword Art Online 2012-07-08   2012     7     8
# 6                           Re:Zero 2016-04-04   2016     4     4
# 7                         Dr. Stone 2019-07-05   2019     7     5
# 8                         One Piece 1999-10-20   1999    10    20
# 9                         Blue Lock 2022-10-09   2022    10     9
#
# ✅ Types de 'Date_Pub' après conversion : datetime64[us]
#
# ✅ Dates converties et extraites avec succès.
# -----------------------------------------------------------------

# %% [markdown]
# ### 3.6 Détection des doublons
# Vérification de la présence de lignes dupliquées dans le dataset.

# %%
# Vérification des doublons dans le dataset
nb_doublons = df.duplicated().sum()

print(f"Il y a {nb_doublons} doublons dans le dataset.")
# Out:
# Il y a 2 doublons dans le dataset.

# %% [markdown]
# ### 3.7 Résumé de l'exploration
# Synthèse des principales caractéristiques du dataset avant nettoyage.

# %%
# === RÉSUMÉ DU DATASET ===
print("="*70)
print("📊 RÉSUMÉ DU DATASET")
print("="*70)

# Dimensions
print(f"\n📐 Dimensions : {df.shape[0]} lignes × {df.shape[1]} colonnes")

# Valeurs manquantes
print(f"\n🔍 Valeurs manquantes par colonne :")
print("-"*70)
missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(2)
missing_df = pd.DataFrame({
    'Valeurs manquantes': missing,
    'Pourcentage (%)': missing_pct
})
print(missing_df[missing_df['Valeurs manquantes'] > 0])

# Doublons
nb_doublons = df.duplicated().sum()
print(f"\n🔄 Doublons : {nb_doublons}")

# Types de données
print(f"\n📋 Types de données :")
print("-"*70)
print(df.dtypes)

print("\n" + "="*70)
# Out:
# ======================================================================
# 📊 RÉSUMÉ DU DATASET
# ======================================================================
#
# 📐 Dimensions : 61 lignes × 20 colonnes
#
# 🔍 Valeurs manquantes par colonne :
# ----------------------------------------------------------------------
#                Valeurs manquantes  Pourcentage (%)
# Comm_Saison_3                  10            16.39
#
# 🔄 Doublons : 2
#
# 📋 Types de données :
# ----------------------------------------------------------------------
# Anime                           str
# Genre_Tags                      str
# Source                          str
# Nb_Episodes                   int64
# Status                          str
# Studio                          str
# Date_Pub             datetime64[us]
# Note_Globale                float64
# Note_Meilleur_Ep            float64
# Meilleur_Ep_Titre               str
# Comm_Meilleur_Ep                str
# Note_Pire_Ep                float64
# Pire_Ep_Titre                   str
# Comm_Pire_Ep                    str
# Comm_Saison_1                   str
# Comm_Saison_2                   str
# Comm_Saison_3                   str
# Annee                         int32
# Mois                          int32
# Jour                          int32
# dtype: object
#
# ======================================================================

# %% [markdown]
# ## 4. 🧹 Nettoyage des données {#nettoyage}
#
# ### 4.1 Suppression des doublons
# Élimination des lignes dupliquées et réinitialisation de l'index pour maintenir une séquence continue.
#
# **Méthode** : `drop_duplicates()` + `reset_index(drop=True)`

# %%
# Suppresion des doublons et reset de l'index pour éviter les trous
df = df.drop_duplicates().reset_index(drop=True)

# Verification du nombre de lignes après suppression des doublons
print(f"✅ Doublons supprimés. Nouveau nombre de lignes : {df.shape[0]}")
# Out:
# ✅ Doublons supprimés. Nouveau nombre de lignes : 59

# %% [markdown]
# ### 4.2 Traitement des valeurs manquantes
# Remplacement de toutes les valeurs manquantes par la chaîne `"Non renseigné"`.
#
# **Stratégie** : Imputation par valeur constante pour éviter la perte d'informations.
#
# > **Alternative possible** : Selon les colonnes, on pourrait utiliser la moyenne, la médiane ou supprimer les lignes.

# %%
# Remplacement des valeurs manquantes par "Non renseigné"
df = df.fillna("Non renseigné")

print("Nombre de valeurs manquantes après imputation :")
print(df.isnull().sum()) # Vérification qu'il n'y a plus de valeurs manquantes
# Out:
# Nombre de valeurs manquantes après imputation :
# Anime                0
# Genre_Tags           0
# Source               0
# Nb_Episodes          0
# Status               0
# Studio               0
# Date_Pub             0
# Note_Globale         0
# Note_Meilleur_Ep     0
# Meilleur_Ep_Titre    0
# Comm_Meilleur_Ep     0
# Note_Pire_Ep         0
# Pire_Ep_Titre        0
# Comm_Pire_Ep         0
# Comm_Saison_1        0
# Comm_Saison_2        0
# Comm_Saison_3        0
# Annee                0
# Mois                 0
# Jour                 0
# dtype: int64

# %% [markdown]
# ### 4.3 Nettoyage des colonnes textuelles
# Normalisation des colonnes de type texte pour assurer la cohérence des données.
#
# **Opérations effectuées** :
# - Suppression des espaces en début/fin (`str.strip()`)
# - Mise en majuscule de la première lettre de chaque mot (`str.title()`)
#
# **Colonnes concernées** : Anime, Genre_Tags, Source, Studio, Status

# %%
# Vérification des colonnes disponibles
print("📋 Colonnes disponibles dans le DataFrame :")
print(df.columns.tolist())
print("-" * 70)

# Colonnes textuelles à nettoyer (vérifiées et adaptées au dataset réel)
cols_textuelles = ['Anime', 'Genre_Tags', 'Source', 'Studio', 'Status']

# Filtrer pour ne garder que les colonnes présentes dans le DataFrame
cols_existantes = [col for col in cols_textuelles if col in df.columns]

print(f"✅ Colonnes à nettoyer : {cols_existantes}")
print("-" * 70)

# Boucle pour nettoyer les espaces et mettre en majuscule la première lettre de chaque mot
for col in cols_existantes:
    # Vérifier que la colonne est bien de type texte
    if df[col].dtype == 'object':
        df[col] = df[col].astype(str).str.strip().str.title()

print(f"✅ {len(cols_existantes)} colonnes textuelles nettoyées avec succès")
# Out:
# 📋 Colonnes disponibles dans le DataFrame :
# ['Anime', 'Genre_Tags', 'Source', 'Nb_Episodes', 'Status', 'Studio', 'Date_Pub', 'Note_Globale', 'Note_Meilleur_Ep', 'Meilleur_Ep_Titre', 'Comm_Meilleur_Ep', 'Note_Pire_Ep', 'Pire_Ep_Titre', 'Comm_Pire_Ep', 'Comm_Saison_1', 'Comm_Saison_2', 'Comm_Saison_3', 'Annee', 'Mois', 'Jour']
# ----------------------------------------------------------------------
# ✅ Colonnes à nettoyer : ['Anime', 'Genre_Tags', 'Source', 'Studio', 'Status']
# ----------------------------------------------------------------------
# ✅ 5 colonnes textuelles nettoyées avec succès

# %% [markdown]
# ## 5. ✅ Vérification finale de la qualité des données {#verification}
#
# Contrôle exhaustif pour s'assurer que le dataset est prêt pour l'analyse et la sauvegarde.
#
# **Points vérifiés** :
# - Absence de valeurs manquantes
# - Absence de doublons
# - Cardinalité des colonnes
# - Statistiques descriptives
# - Cohérence des types de données
# - Détection de valeurs aberrantes (scores négatifs, années impossibles)
# - Espaces parasites dans les colonnes textuelles

# %%
# === VÉRIFICATION FINALE DE LA QUALITÉ DES DONNÉES ===
print("="*70)
print("🔍 VÉRIFICATION FINALE DE LA QUALITÉ DES DONNÉES")
print("="*70)

# 1. Valeurs manquantes
print("\n1️⃣ Valeurs manquantes :")
print(f"   Total : {df.isnull().sum().sum()}")

# 2. Doublons
print("\n2️⃣ Doublons :")
print(f"   Total : {df.duplicated().sum()}")

# 3. Valeurs uniques par colonne (pour détecter des anomalies)
print("\n3️⃣ Cardinalité des colonnes :")
print("-"*70)
for col in df.columns:
    n_unique = df[col].nunique()
    print(f"   {col:20} : {n_unique:6} valeurs uniques")

# 4. Statistiques sur colonnes numériques
print("\n4️⃣ Statistiques descriptives (colonnes numériques) :")
print("-"*70)
print(df.describe())

# 5. Vérification des types de données
print("\n5️⃣ Types de données :")
print("-"*70)
print(df.dtypes)

# 6. Vérification de valeurs aberrantes potentielles
print("\n6️⃣ Valeurs aberrantes potentielles :")
print("-"*70)

# Score négatif ?
if 'Score' in df.columns:
    scores_negatifs = (df['Score'] < 0).sum()
    print(f"   Scores négatifs : {scores_negatifs}")
    
# Années aberrantes ?
if 'Annee' in df.columns:
    annee_min = df['Annee'].min()
    annee_max = df['Annee'].max()
    print(f"   Plage d'années : {annee_min} - {annee_max}")
    if annee_min < 1900 or annee_max > 2026:
        print("   ⚠️  Années suspectes détectées !")

# 7. Espaces en début/fin de chaînes (colonnes texte)
print("\n7️⃣ Espaces parasites (colonnes texte) :")
print("-"*70)
text_cols = df.select_dtypes(include=['object']).columns
espaces_detectes = False
for col in text_cols:
    has_spaces = (df[col].astype(str).str.strip() != df[col].astype(str)).sum()
    if has_spaces > 0:
        print(f"   ⚠️  {col} : {has_spaces} valeurs avec espaces parasites")
        espaces_detectes = True

if not espaces_detectes:
    print("   ✅ Aucun espace parasite détecté")

print("\n" + "="*70)
print("✅ Vérification terminée !")
print("="*70)
# Out:
# ======================================================================
# 🔍 VÉRIFICATION FINALE DE LA QUALITÉ DES DONNÉES
# ======================================================================
#
# 1️⃣ Valeurs manquantes :
#    Total : 0
#
# 2️⃣ Doublons :
#    Total : 0
#
# 3️⃣ Cardinalité des colonnes :
# ----------------------------------------------------------------------
#    Anime                :     59 valeurs uniques
#    Genre_Tags           :     44 valeurs uniques
#    Source               :      6 valeurs uniques
#    Nb_Episodes          :     38 valeurs uniques
#    Status               :      3 valeurs uniques
#    Studio               :     24 valeurs uniques
#    Date_Pub             :     57 valeurs uniques
#    Note_Globale         :     19 valeurs uniques
#    Note_Meilleur_Ep     :     17 valeurs uniques
#    Meilleur_Ep_Titre    :     59 valeurs uniques
#    Comm_Meilleur_Ep     :     59 valeurs uniques
#    Note_Pire_Ep         :     27 valeurs uniques
#    Pire_Ep_Titre        :     59 valeurs uniques
#    Comm_Pire_Ep         :     59 valeurs uniques
#    Comm_Saison_1        :     59 valeurs uniques
#    Comm_Saison_2        :     59 valeurs uniques
#    Comm_Saison_3        :     47 valeurs uniques
#    Annee                :     26 valeurs uniques
#    Mois                 :      8 valeurs uniques
#    Jour                 :     19 valeurs uniques
#
# 4️⃣ Statistiques descriptives (colonnes numériques) :
# ----------------------------------------------------------------------
#        Nb_Episodes                    Date_Pub  Note_Globale  \
# count    59.000000                          59     59.000000
# mean     91.864407  2013-01-13 13:01:01.016949      8.323729
# min       3.000000         1989-04-26 00:00:00      6.000000
# 25%      24.000000         2006-12-11 00:00:00      8.150000
# 50%      37.000000         2014-07-04 00:00:00      8.400000
# 75%      75.500000         2019-07-06 12:00:00      8.650000
# max    1090.000000         2025-04-07 00:00:00      9.300000
# std     164.602181                         NaN      0.523693
#
#        Note_Meilleur_Ep  Note_Pire_Ep        Annee       Mois       Jour
# count         59.000000     59.000000    59.000000  59.000000  59.000000
# mean           9.323729      6.703390  2012.542373   6.694915   8.542373
# min            8.200000      0.000000  1989.000000   1.000000   1.000000
# 25%            9.100000      6.200000  2006.500000   4.000000   5.000000
# 50%            9.400000      7.200000  2014.000000   7.000000   7.000000
# 75%            9.700000      7.500000  2019.000000  10.000000   9.500000
# max            9.900000      8.400000  2025.000000  10.000000  30.000000
# std            0.456123      1.388123     8.971837   3.228399   6.621079
#
# 5️⃣ Types de données :
# ----------------------------------------------------------------------
# Anime                           str
# Genre_Tags                      str
# Source                          str
# Nb_Episodes                   int64
# Status                          str
# Studio                          str
# Date_Pub             datetime64[us]
# Note_Globale                float64
# Note_Meilleur_Ep            float64
# Meilleur_Ep_Titre               str
# Comm_Meilleur_Ep                str
# Note_Pire_Ep                float64
# Pire_Ep_Titre                   str
# Comm_Pire_Ep                    str
# Comm_Saison_1                   str
# Comm_Saison_2                   str
# Comm_Saison_3                   str
# Annee                         int32
# Mois                          int32
# Jour                          int32
# dtype: object
#
# 6️⃣ Valeurs aberrantes potentielles :
# ----------------------------------------------------------------------
#    Plage d'années : 1989 - 2025
#
# 7️⃣ Espaces parasites (colonnes texte) :
# ----------------------------------------------------------------------
#    ⚠️  Comm_Saison_3 : 1 valeurs avec espaces parasites
#
# ======================================================================
# ✅ Vérification terminée !
# ======================================================================
# /var/folders/sv/4ghqxf1d38q241yb7kp136jh0000gp/T/ipykernel_79275/1493299153.py:51: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   text_cols = df.select_dtypes(include=['object']).columns

# %% [markdown]
# ## 6. 💾 Sauvegarde du dataset nettoyé {#sauvegarde}
#
# Export du dataset nettoyé dans un nouveau fichier CSV.
#
# **Fichier de sortie** : `data/animes_cleaned.csv`
#
# **Modifications appliquées** :
# - ✅ Doublons supprimés
# - ✅ Valeurs manquantes traitées
# - ✅ Colonnes textuelles nettoyées
# - ✅ Dates converties en format datetime
# - ✅ Colonnes temporelles ajoutées (Annee, Mois, Jour)
# - ✅ Qualité des données vérifiée

# %%
# Sauvegarde du dataset nettoyé
df.to_csv("data/animes_cleaned.csv", index=False)

print("✅ Dataset nettoyé sauvegardé sous 'data/animes_cleaned.csv'")
# Out:
# ✅ Dataset nettoyé sauvegardé sous 'data/animes_cleaned.csv'

# %%
# BONUS : Importation de la librairie matplotlib et seaborn pour visualisation
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
print("✅ Librairies de visualisation importées avec succès")

# Rechargement du dataset nettoyé
df = pd.read_csv("data/animes_cleaned.csv")

df = df[df['Note_Pire_Ep'] > 0] 
print(f"✅ Dataset rechargé avec {df.shape[0]} lignes après filtrage des notes > 0")

# Reconverstion des dates au cas où changement après chargement
df['Date_Pub'] = pd.to_datetime(df['Date_Pub'])

print("✅ EDA Initialisé.")
print(f"Nombre d'animes restant pour l'analyse : {df.shape[0]}")
print(f"Note min et max épisode - min: {df['Note_Pire_Ep'].min()}, max: {df['Note_Pire_Ep'].max()}")
# Out:
# ✅ Librairies de visualisation importées avec succès
# ✅ Dataset rechargé avec 58 lignes après filtrage des notes > 0
# ✅ EDA Initialisé.
# Nombre d'animes restant pour l'analyse : 58
# Note min et max épisode - min: 2.7, max: 8.4
